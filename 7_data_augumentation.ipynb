# %%
# !pip show ctgan
# Out:
# Name: ctgan
# Version: 0.10.2
# Summary: Create tabular synthetic data using a conditional GAN
# Home-page:
# Author:
# Author-email: "DataCebo, Inc." <info@sdv.dev>
# License: BSL-1.1
# Location: C:\Users\S.A.N\anaconda3\Lib\site-packages
# Requires: numpy, pandas, rdt, torch, tqdm
# Required-by:

# %%
# !pip install ctgan==0.9.0 seaborn==0.11.2 pandas==2.2.1

# %%
import seaborn as sns
import pandas as pd
from ctgan import CTGAN

# %%
iris_data = sns.load_dataset("iris")
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
categorical_features= iris_data.select_dtypes(exclude="number").columns.tolist()

# %%
categorical_features
# Out:
# ['species']

# %%
ctgan = CTGAN(epochs=5)
ctgan.fit(iris_data, categorical_features)

# %%
synthetic_iris = ctgan.sample(1000)
synthetic_iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0       5.812173     4.412351      3.080052     0.647010   virginica
# 1       4.461134     3.979790      3.193720     0.265853   virginica
# 2       5.561289     3.580996     -0.034873    -0.049147      setosa
# 3       4.922449     3.437196      2.418104     2.480315   virginica
# 4       4.706247     4.705650      3.393802     2.693134   virginica
# 5       4.231515     3.269832      0.599372     0.327208   virginica
# 6       6.313292     2.607717      0.257436     1.965308  versicolor
# 7       4.244353     3.638872      3.562045     2.467617   virginica
# 8       4.147562     4.230477      1.208356     0.223223  versicolor
# 9       5.189172     3.478138      2.659325     2.724275      setosa
# 10      4.720654     3.173879      4.406204     0.487006   virginica
# 11      5.082449     3.337284      1.462755     1.602265   virginica
# 12      6.939935     3.537685      2.777048     1.437987  versicolor
# 13      5.235322     3.484887      2.775434     0.968879      setosa
# 14      6.711887     3.139998      3.513202     0.007495  versicolor
# 15      7.574634     2.628896      3.069404     0.670821   virginica
# 16      4.179214     3.559279      4.007286     0.526540      setosa
# 17      4.363397     4.116583      0.492464     2.033733   virginica
# 18      5.123378     4.753404      0.470309     0.396545      setosa
# 19      6.036578     2.657621      0.249979     1.751954  versicolor

# %%
synthetic_iris.to_csv("synthetic_iris_data.csv", index=False)
print("Synthetic data saved to 'synthetic_iris_data.csv'")
# Out:
# Synthetic data saved to 'synthetic_iris_data.csv'

# %%
# !pip show streamlit
# Out:
# WARNING: Package(s) not found: streamlit

# %%
# !pip install streamlit==1.31.1
# Out:
# Collecting streamlit==1.31.1
#   Obtaining dependency information for streamlit==1.31.1 from https://files.pythonhosted.org/packages/c5/ea/b50f166fb6e5c244568f798ade98fa261b82588ab9ad83230b327a82b42f/streamlit-1.31.1-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.31.1-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting altair<6,>=4.0 (from streamlit==1.31.1)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit==1.31.1)
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\s.a.n\appdata\roaming\python\python311\site-packages (from streamlit==1.31.1) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (8.0.4)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\s.a.n\appdata\roaming\python\python311\site-packages (from streamlit==1.31.1) (2.1.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (4.25.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit==1.31.1)
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/19/71/39c7c0d87f8d4e6c020a393182060eaefeeae6c01dab6a84ec346f2567df/rich-13.9.4-py3-none-any.whl.metadata
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (4.12.2)
# Collecting tzlocal<6,>=1.1 (from streamlit==1.31.1)
#   Obtaining dependency information for tzlocal<6,>=1.1 from https://files.pythonhosted.org/packages/97/3f/c4c51c55ff8487f2e6d0e618dba917e3c3ee2caae6cf0fbb59c9b1876f2e/tzlocal-5.2-py3-none-any.whl.metadata
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit==1.31.1)
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/6e/78/36828a4d857b25896f9774c875714ba4e9b3bc8a92d2debe3f4df3a83d4f/validators-0.34.0-py3-none-any.whl.metadata
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit==1.31.1)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/1d/9a/4114a9057db2f1462d5c8f8390ab7383925fe1ac012eaa42402ad65c2963/GitPython-3.1.44-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit==1.31.1)
#   Obtaining dependency information for pydeck<1,>=0.8.0b4 from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\s.a.n\anaconda3\lib\site-packages (from streamlit==1.31.1) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\s.a.n\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.1) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.1) (4.17.3)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit==1.31.1)
#   Obtaining dependency information for narwhals>=1.14.2 from https://files.pythonhosted.org/packages/38/13/23b73a1f300521613f967763ef4ada4737474f9d5b620b7e5ba9e4857ee7/narwhals-1.23.0-py3-none-any.whl.metadata
#   Downloading narwhals-1.23.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: colorama in c:\users\s.a.n\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit==1.31.1) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.1)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\s.a.n\anaconda3\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit==1.31.1) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\s.a.n\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.31.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\s.a.n\appdata\roaming\python\python311\site-packages (from pandas<3,>=1.3.0->streamlit==1.31.1) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\s.a.n\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit==1.31.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\s.a.n\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s.a.n\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\s.a.n\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\s.a.n\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit==1.31.1) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.31.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.31.1) (2.15.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.1)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.31.1) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.1) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\s.a.n\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.1) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\s.a.n\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.31.1) (0.1.0)
# Downloading streamlit-1.31.1-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.4 MB 5.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/8.4 MB 7.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/8.4 MB 7.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.4 MB 10.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.4 MB 10.4 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.4 MB 10.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.0/8.4 MB 10.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.6/8.4 MB 11.0 MB/s eta 0:00:01
#    ------------------- -------------------- 4.1/8.4 MB 11.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.4 MB 11.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.3/8.4 MB 11.6 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.4 MB 11.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.4/8.4 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.4 MB 11.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.4/8.4 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.9/8.4 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 10.9 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------- ----------- 522.2/731.2 kB 16.5 MB/s eta 0:00:01
#    --------------------------------------- 731.2/731.2 kB 11.4 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/207.6 kB ? eta -:--:--
#    -------------------------------- ------ 174.1/207.6 kB 10.2 MB/s eta 0:00:01
#    -------------------------------- ------ 174.1/207.6 kB 10.2 MB/s eta 0:00:01
#    -------------------------------- ------ 174.1/207.6 kB 10.2 MB/s eta 0:00:01
#    -------------------------------- ------ 174.1/207.6 kB 10.2 MB/s eta 0:00:01
#    ----------------------------------- -- 194.6/207.6 kB 841.6 kB/s eta 0:00:01
#    -------------------------------------- 207.6/207.6 kB 843.4 kB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.9 MB 7.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/6.9 MB 8.5 MB/s eta 0:00:01
#    -------- ------------------------------- 1.4/6.9 MB 9.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.9/6.9 MB 10.1 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.9 MB 10.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.0/6.9 MB 10.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.5/6.9 MB 10.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 10.5 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.9 MB 10.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.9 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 5.6/6.9 MB 10.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.2/6.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/6.9 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  6.9/6.9 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 10.5 MB/s eta 0:00:00
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ---------------------------------------- 0.0/242.4 kB ? eta -:--:--
#    ---------------------------------------- 242.4/242.4 kB 7.5 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#    ---------------------------------------- 43.5/43.5 kB ? eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# Downloading narwhals-1.23.0-py3-none-any.whl (306 kB)
#    ---------------------------------------- 0.0/306.2 kB ? eta -:--:--
#    ---------------------------------------- 306.2/306.2 kB 9.5 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: validators, tzlocal, smmap, narwhals, blinker, rich, pydeck, gitdb, altair, gitpython, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.23.0 pydeck-0.9.1 rich-13.9.4 smmap-5.0.2 streamlit-1.31.1 tzlocal-5.2 validators-0.34.0
